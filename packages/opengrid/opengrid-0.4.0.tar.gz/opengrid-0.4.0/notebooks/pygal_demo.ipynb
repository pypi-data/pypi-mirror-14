# %%
import sys
reload(sys)
sys.setdefaultencoding('UTF8')

# %%
from __future__ import unicode_literals

# %matplotlib inline
from IPython.display import SVG, HTML
# Out:
# 'IPython.core.display'

# %%
html_pygal = """
<!DOCTYPE html>
<html>
  <head>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
  <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
    <!-- ... -->
  </head>
  <body>
    <figure>
      {pygal_render}
    </figure>
  </body>
</html>
"""

# %%
import pygal
line_chart = pygal.Line()
line_chart.title = 'Browser usage evolution (in %)'
line_chart.x_labels = map(str, range(2002, 2013))
line_chart.add('Firefox', [None, None, 0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
line_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
line_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
line_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
HTML(html_pygal.format(pygal_render=line_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-c65b15e9-ca3c-449f-b285-c9f9676cddff" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.1.1 (lxml) ©Kozea 2011-2015 on 2016-02-18--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-c65b15e9-ca3c-449f-b285-c9f9676cddff{background-color:rgba(249,249,249,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff path,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff rect,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .graph{fill:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff text.no_data{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .title{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .legends .legend text{fill:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .line{stroke:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis text.major{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y .guides:hover .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .line-graph .axis.x .guides:hover .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .stackedline-graph .axis.x .guides:hover .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .reactive{fill-opacity:.7}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .ci{stroke:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .reactive.active,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .active .reactive{fill-opacity:.8;stroke-width:4}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .series text{fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .label{fill:rgba(0,0,0,.87)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .tooltip .value{font-size:1.5em}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .map-element .reactive{fill-opacity:inherit}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-0,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-1,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-2,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-2 a:visited{stroke:#009688;fill:#009688}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-3,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay .color-0 text{fill:black}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay .color-1 text{fill:black}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay .color-2 text{fill:black}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .text-overlay .color-3 text{fill:black}
# #chart-c65b15e9-ca3c-449f-b285-c9f9676cddff text.no_data{text-anchor:middle}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .guide.line{fill:none}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .centered{text-anchor:middle}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .title{text-anchor:middle}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .legends .legend text{fill-opacity:1}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.x text{text-anchor:middle}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.x:not(.web) text[transform]{text-anchor:start}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y text{text-anchor:end}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y text[transform].backwards{text-anchor:start}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y2 text{text-anchor:start}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y2 text[transform].backwards{text-anchor:end}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .guide.line{stroke-dasharray:4,4}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .major.guide.line{stroke-dasharray:6,6}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .horizontal .axis.y .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .horizontal .axis.y2 .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .vertical .axis.x .guide.line{opacity:0}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .horizontal .axis.always_show .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y .guides:hover .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.y2 .guides:hover .guide.line,#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis.x .guides:hover .guide.line{opacity:1}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .axis .guides:hover text{opacity:1}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .nofill{fill:none}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .subtle-fill{fill-opacity:.2}#chart-c65b15e9-ca3c-449f-b285-c9f9676cddff .dot{stroke-width:1px;fill-opacity:1}#char

# %%
stackedline_chart = pygal.StackedLine(fill=True)
stackedline_chart.title = 'Browser usage evolution (in %)'
stackedline_chart.x_labels = map(str, range(2002, 2013))
stackedline_chart.add('Firefox', [None, None, 0, 16.6,   25,   31, 36.4, 45.5, 46.3, 42.8, 37.1])
stackedline_chart.add('Chrome',  [None, None, None, None, None, None,    0,  3.9, 10.8, 23.8, 35.3])
stackedline_chart.add('IE',      [85.8, 84.6, 84.7, 74.5,   66, 58.6, 54.7, 44.8, 36.2, 26.6, 20.1])
stackedline_chart.add('Others',  [14.2, 15.4, 15.3,  8.9,    9, 10.4,  8.9,  5.8,  6.7,  6.8,  7.5])
HTML(html_pygal.format(pygal_render=stackedline_chart.render()))
# Out:
# <!DOCTYPE html>
# <html>
#   <head>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#   <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/pygal-tooltips.js"></script>
#     <!-- ... -->
#   </head>
#   <body>
#     <figure>
#       <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-40ecca7c-037a-4a76-bcc3-83af49431ebe" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 2.1.1 (lxml) ©Kozea 2011-2015 on 2016-02-18--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-40ecca7c-037a-4a76-bcc3-83af49431ebe{background-color:rgba(249,249,249,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe path,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe rect,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .graph{fill:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe text.no_data{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .title{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .legends .legend text{fill:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .line{stroke:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis text.major{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y .guides:hover .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .line-graph .axis.x .guides:hover .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .stackedline-graph .axis.x .guides:hover .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .reactive{fill-opacity:.7}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .ci{stroke:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .reactive.active,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .active .reactive{fill-opacity:.8;stroke-width:4}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .series text{fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .label{fill:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .label{fill:rgba(0,0,0,.87)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .tooltip .value{font-size:1.5em}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .map-element .reactive{fill-opacity:inherit}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-0,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-1,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-2,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-2 a:visited{stroke:#009688;fill:#009688}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-3,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay .color-0 text{fill:black}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay .color-1 text{fill:black}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay .color-2 text{fill:black}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .text-overlay .color-3 text{fill:black}
# #chart-40ecca7c-037a-4a76-bcc3-83af49431ebe text.no_data{text-anchor:middle}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .guide.line{fill:none}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .centered{text-anchor:middle}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .title{text-anchor:middle}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .legends .legend text{fill-opacity:1}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.x text{text-anchor:middle}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.x:not(.web) text[transform]{text-anchor:start}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y text{text-anchor:end}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y text[transform].backwards{text-anchor:start}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y2 text{text-anchor:start}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y2 text[transform].backwards{text-anchor:end}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .guide.line{stroke-dasharray:4,4}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .major.guide.line{stroke-dasharray:6,6}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .horizontal .axis.y .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .horizontal .axis.y2 .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .vertical .axis.x .guide.line{opacity:0}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .horizontal .axis.always_show .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y .guides:hover .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.y2 .guides:hover .guide.line,#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis.x .guides:hover .guide.line{opacity:1}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .axis .guides:hover text{opacity:1}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .nofill{fill:none}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .subtle-fill{fill-opacity:.2}#chart-40ecca7c-037a-4a76-bcc3-83af49431ebe .dot{stroke-width:1px;fill-opacity:1}#char
